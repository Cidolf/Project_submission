# %% [markdown]
# # Proyek Analisis Data: E-Commerce Public Dataset
# - **Nama:** Muhammad Arqam Syahputra
# - **Email:** arqamscp@gmail.com
# - **ID Dicoding:** muhammadarqam

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana trend performa pemesanan dan pendapatan produk per bulan?
# - Produk apa yang memiliki total pemesanan terbanyak dan terendah?
# - Kota mana yang melakukan banyak pemesanan?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# ##### Mengumpulkan data customers

# %%
customers_file = 'D:\\SEMESTER 6\\Bangkit\\Belajar Analisis Data dengan Python\\Proyek Analisis Data\\E-Commerce Public Dataset\\customers_dataset.csv'
customers_df = pd.read_csv(customers_file)
customers_df.head(10)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# 5  879864dab9bc3047522c92c82e1212b8  4c93744516667ad3b8f1fb645a3116a4
# 6  fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
# 7  5e274e7a0c3809e14aba7ad5aae0d407  57b2a98a409812fe9618067b6b8ebe4f
# 8  5adf08e34b2e993982a47070956c5c65  1175e95fb47ddff9de6b2b06188f7e0d
# 9  4b7139f34592b3a31687243a302fa75b  9afe194fb833f79e300e37e580171f22
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# ...

# %% [markdown]
# ##### Mengumpulkan data order items

# %%
order_items_file = 'D:\\SEMESTER 6\\Bangkit\\Belajar Analisis Data dengan Python\\Proyek Analisis Data\\E-Commerce Public Dataset\\order_items_dataset.csv'
order_items_df = pd.read_csv(order_items_file)
order_items_df.head(10)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
# 5  00048cc3ae777c65dbb7d2a0634bc1ea              1
# 6  00054e8431b9d7675808bcb819fb4a32              1
# 7  000576fe39319847cbb9d288c5617fa6              1
# 8  0005a1a1728c9d785b8e2b08b904576c              1
# 9  0005f50442cb953dcd1d21e1fb923495              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# ...

# %% [markdown]
# ##### Mengumpulkan data orders

# %%
orders_file = 'D:\\SEMESTER 6\\Bangkit\\Belajar Analisis Data dengan Python\\Proyek Analisis Data\\E-Commerce Public Dataset\\orders_dataset.csv'
orders_df = pd.read_csv(orders_file)
orders_df.head(10)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# 5  a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
# 6  136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 7  6514b8ad8028c9f2cc2374ded245783f  9bdf08b4b3b52b5526ff42d37d47f222
# 8  76c6e866289321a7c93b82b54852dc33  f54a9f0e6b351c431402b8461ea51999
# 9  e69bfb5eb88e0ed6a785585b27e16dbf  31ad1d1b63eb9962463f764d4e6e0c9d
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# ...

# %% [markdown]
# ##### Mengumpulkan data products

# %%
products_file = 'D:\\SEMESTER 6\\Bangkit\\Belajar Analisis Data dengan Python\\Proyek Analisis Data\\E-Commerce Public Dataset\\products_dataset.csv'
products_df = pd.read_csv(products_file)
products_df.head(10)
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
# 5  41d3672d4792049fa1779bb35283ed13  instrumentos_musicais
# 6  732bd381ad09e530fe0a5f457d81becb             cool_stuff
# 7  2548af3e6e77a690cf3eb6368e9ab61e       moveis_decoracao
# 8  37cc742be07708b53a98702e77a21a02       eletrodomesticos
# 9  8c92109888e8cdf9d66dc7e463025574             brinquedos
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# ...

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# ##### Menilai data customers

# %% [markdown]
# memeriksa tipe data

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %% [markdown]
# Memeriksa missing value

# %%
customers_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %% [markdown]
# Memeriksa duplikasi data dan memeriksa parameter statistik dari kolom numerik

# %%
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
customers_df.describe()
# Out:
# Jumlah duplikasi:  0
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# untuk data customers tidak ada masalah

# %% [markdown]
# ##### Menilai data orders

# %% [markdown]
# memeriksa tipe data

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %% [markdown]
# Memeriksa missing value

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# Memeriksa duplikasi data dan memeriksa parameter statistik dari kolom numerik

# %%
print("Jumlah duplikasi: ", orders_df.duplicated().sum())
orders_df.describe()
# Out:
# Jumlah duplikasi:  0
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %% [markdown]
# - Terdapat kesalahan tipe data untuk kolom order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date & order_estimated_delivery_date.
# - Terdapat 160 missing value pada kolom order_approved_at, 1783 missing value pada kolom order_delivered_carrier_date & 2965 missing value pada kolom order_delivered_customer_date.

# %% [markdown]
# ##### Menilai data orders_items

# %% [markdown]
# memeriksa tipe data

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %% [markdown]
# Memeriksa missing value

# %%
order_items_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %% [markdown]
# Memeriksa duplikasi data dan memeriksa parameter statistik dari kolom numerik

# %%
print("Jumlah duplikasi: ", order_items_df.duplicated().sum())
order_items_df.describe()
# Out:
# Jumlah duplikasi:  0
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# Terdapat kesalahan tipe data untuk kolom shipping_limit_date

# %% [markdown]
# ##### Menilai data products

# %% [markdown]
# memeriksa tipe data

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# Memeriksa missing value

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %% [markdown]
# Memeriksa duplikasi data dan memeriksa parameter statistik dari kolom numerik

# %%
print("Jumlah duplikasi: ", products_df.duplicated().sum())
products_df.describe()
# Out:
# Jumlah duplikasi:  0
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %% [markdown]
# Terdapat 610 missing value  pada kolom product_category_name, product_name_lenght, product_description_lenght, product_photos_qty, dan terdapat 2 missing value pada kolom product_weight_g, product_length_cm, product_height_cm, product_width_cm

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# ##### Membersihkan data orders

# %% [markdown]
# Mengubah tipe data

# %%
datetime_columns = ["order_purchase_timestamp", "order_approved_at", "order_delivered_carrier_date", "order_delivered_customer_date", "order_estimated_delivery_date"]
 
for column in datetime_columns:
  orders_df[column] = pd.to_datetime(orders_df[column])

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# Cek missing value

# %%
orders_df[orders_df.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %% [markdown]
# hapus missing value menggunakan fungsi dropna()

# %%
orders_df.dropna(subset=['order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date'], inplace=True)

# %%
orders_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# ##### Membersihkan data order_items

# %% [markdown]
# mengubah tipe data

# %%
datetime_columns = ["shipping_limit_date"]
 
for column in datetime_columns:
  order_items_df[column] = pd.to_datetime(order_items_df[column])

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %% [markdown]
# #### Membersihkan data products

# %% [markdown]
# Mengecek missing value

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
products_df[products_df.product_category_name.isna()]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %% [markdown]
# Menghapus missing value menggunakan dropna()

# %%
products_df.dropna(subset=['product_category_name', 'product_name_lenght', 'product_description_lenght', 'product_photos_qty', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm'], inplace=True)

# %%
products_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32340 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32340 non-null  object
#  1   product_category_name       32340 non-null  object
#  2   product_name_lenght         32340 non-null  float64
#  3   product_description_lenght  32340 non-null  float64
#  4   product_photos_qty          32340 non-null  float64
#  5   product_weight_g            32340 non-null  float64
#  6   product_length_cm           32340 non-null  float64
#  7   product_height_cm           32340 non-null  float64
#  8   product_width_cm            32340 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.5+ MB

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %% [markdown]
# Menggabungkan semua data

# %%
orders_items_df = pd.merge(orders_df, order_items_df, how='inner', on='order_id')
products_order_df = pd.merge(orders_items_df, products_df, how='inner', on='product_id')
data_ecommerce_df = pd.merge(products_order_df, customers_df, how='inner', on='customer_id')

data_ecommerce_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# Mengecek missing value

# %%
data_ecommerce_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# order_item_id                    0
# product_id                       0
# seller_id                        0
# shipping_limit_date              0
# price                            0
# freight_value                    0
# product_category_name            0
# product_name_lenght              0
# product_description_lenght       0
# product_photos_qty               0
# product_weight_g                 0
# product_length_cm                0
# product_height_cm                0
# product_width_cm                 0
# customer_unique_id               0
# customer_zip_code_prefix         0
# customer_city                    0
# customer_state                   0
# dtype: int64

# %%
data_ecommerce_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108643 entries, 0 to 108642
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       108643 non-null  object
#  1   customer_id                    108643 non-null  object
#  2   order_status                   108643 non-null  object
#  3   order_purchase_timestamp       108643 non-null  datetime64[ns]
#  4   order_approved_at              108643 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   108643 non-null  datetime64[ns]
#  6   order_delivered_customer_date  108643 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  108643 non-null  datetime64[ns]
#  8   order_item_id                  108643 non-null  int64
#  9   product_id                     108643 non-null  object
#  10  seller_id                      108643 non-null  object
# ...

# %% [markdown]
# memastikan bahwa tipe data sudah tepat

# %%
data_ecommerce_df['order_purchase_timestamp']=pd.to_datetime(data_ecommerce_df['order_purchase_timestamp'])
data_ecommerce_df['purchase_month_year'] = data_ecommerce_df['order_purchase_timestamp'].dt.strftime('%B %Y')
data_ecommerce_df['purchase_month_year'] = pd.to_datetime(data_ecommerce_df['purchase_month_year'], format='%B %Y')

data_ecommerce_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108643 entries, 0 to 108642
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       108643 non-null  object
#  1   customer_id                    108643 non-null  object
#  2   order_status                   108643 non-null  object
#  3   order_purchase_timestamp       108643 non-null  datetime64[ns]
#  4   order_approved_at              108643 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   108643 non-null  datetime64[ns]
#  6   order_delivered_customer_date  108643 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  108643 non-null  datetime64[ns]
#  8   order_item_id                  108643 non-null  int64
#  9   product_id                     108643 non-null  object
#  10  seller_id                      108643 non-null  object
# ...

# %% [markdown]
# menghapus data yang tidak diperlukan

# %%
columns_drop = ['order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date', 'order_approved_at', 'seller_id', 'shipping_limit_date', 'product_photos_qty', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm', 'product_name_lenght', 'product_description_lenght', 'customer_unique_id', 'customer_zip_code_prefix']
data_ecommerce_df.drop(columns=columns_drop, inplace=True)
data_ecommerce_df.T
# Out:
#                                                     0       \
# order_id                  e481f51cbdc54678b7cc49136f2d6af7
# customer_id               9ef432eb6251297304e76186b10a928d
# order_status                                     delivered
# order_purchase_timestamp               2017-10-02 10:56:33
# order_item_id                                            1
# product_id                87285b34884572647811a353c7ac498a
# price                                                29.99
# freight_value                                         8.72
# product_category_name                utilidades_domesticas
# customer_city                                    sao paulo
# customer_state                                          SP
# purchase_month_year                    2017-10-01 00:00:00
#
#                                                     1       \
# order_id                  53cdb2fc8bc7dce0b6741e2150273451
# customer_id               b0830fb4747a6c6d20dea0b8c802d7ef
# ...

# %% [markdown]
# cek order status yang delivered karena hanya itu yang akan kita gunakan

# %%
data_ecommerce_df.order_status.value_counts()
# Out:
# order_status
# delivered    108636
# canceled          7
# Name: count, dtype: int64

# %%
data_ecommerce_df[(data_ecommerce_df['order_status'] == 'canceled')]
# Out:
#                                 order_id                       customer_id  \
# 3161    1950d777989f6a877539f53795b4c3c3  1bccb206de9f0f25adc6871a1bcf77b2
# 9568    dabf2b0e35b423f94618bf965fcb7514  5cdec0bb8cbdf53ffc8fdc212cd247c6
# 9569    dabf2b0e35b423f94618bf965fcb7514  5cdec0bb8cbdf53ffc8fdc212cd247c6
# 63576   770d331c84e5b214bd9dc70a10b829d0  6c57e6119369185e575b36712766b0ef
# 64716   8beb59392e21af5eb9547ae1a9938d06  bf609b5741f71697f65ce3852c5d2623
# 101150  65d1e226dfaeb8cdc42f665422522d14  70fc57eeae292675927697fe03ad3ff5
# 103143  2c45c33d2f9cb8ff8b1c86cc28c11c30  de4caa97afa80c8eeac2ff4c8da5b72e
#
#        order_status order_purchase_timestamp  order_item_id  \
# 3161       canceled      2018-02-19 19:48:52              1
# 9568       canceled      2016-10-09 00:56:52              1
# 9569       canceled      2016-10-09 00:56:52              2
# 63576      canceled      2016-10-07 14:52:30              1
# 64716      canceled      2016-10-08 20:17:50              1
# ...

# %% [markdown]
# menghapus order status canceled

# %%
data_ecommerce_df[(data_ecommerce_df['order_status'] != 'canceled')]
data_ecommerce_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp  order_item_id  \
# 0    delivered      2017-10-02 10:56:33              1
# 1    delivered      2018-07-24 20:41:37              1
# 2    delivered      2018-08-08 08:38:49              1
# 3    delivered      2017-11-18 19:28:06              1
# 4    delivered      2018-02-13 21:18:39              1
#
#                          product_id   price  freight_value  \
# 0  87285b34884572647811a353c7ac498a   29.99           8.72
# 1  595fac2a385ac33a80bd5114aec74eb8  118.70          22.76
# ...

# %% [markdown]
# Menghapus data outlier, kita akan menghapus tahun 2016 karena datanya sedikit dan tidak lengkap

# %%
data_ecommerce_df['purchase_month_year'].value_counts().sort_index(ascending=True)
# Out:
# purchase_month_year
# 2016-09-01       3
# 2016-10-01     317
# 2016-12-01       1
# 2017-01-01     898
# 2017-02-01    1790
# 2017-03-01    2837
# 2017-04-01    2500
# 2017-05-01    3912
# 2017-06-01    3431
# 2017-07-01    4358
# 2017-08-01    4722
# 2017-09-01    4663
# 2017-10-01    5146
# 2017-11-01    8356
# 2017-12-01    6050
# 2018-01-01    7844
# 2018-02-01    7402
# 2018-03-01    7884
# 2018-04-01    7753
# 2018-05-01    7768
# 2018-06-01    6984
# 2018-07-01    6913
# 2018-08-01    7111
# Name: count, dtype: int64

# %%
data_ecommerce_df = data_ecommerce_df[data_ecommerce_df['purchase_month_year'].dt.year > 2016]
data_ecommerce_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp  order_item_id  \
# 0    delivered      2017-10-02 10:56:33              1
# 1    delivered      2018-07-24 20:41:37              1
# 2    delivered      2018-08-08 08:38:49              1
# 3    delivered      2017-11-18 19:28:06              1
# 4    delivered      2018-02-13 21:18:39              1
#
#                          product_id   price  freight_value  \
# 0  87285b34884572647811a353c7ac498a   29.99           8.72
# 1  595fac2a385ac33a80bd5114aec74eb8  118.70          22.76
# ...

# %% [markdown]
# Total order

# %%
total_order = (data_ecommerce_df['order_id'].count())
total_order
# Out:
# 108322

# %%
total_product_category = data_ecommerce_df.groupby(by='product_category_name').order_id.nunique().sort_values(ascending=False).reset_index()
total_product_category
# Out:
#             product_category_name  order_id
# 0                 cama_mesa_banho      9266
# 1                    beleza_saude      8611
# 2                   esporte_lazer      7510
# 3          informatica_acessorios      6517
# 4                moveis_decoracao      6254
# ..                            ...       ...
# 68                     la_cuisine        13
# 69              cds_dvds_musicais        12
# 70                       pc_gamer         7
# 71  fashion_roupa_infanto_juvenil         7
# 72             seguros_e_servicos         2
#
# [73 rows x 2 columns]

# %% [markdown]
# Total order berdasarkan kota

# %%
data_ecommerce_df.groupby(by='customer_city').order_id.nunique().sort_values(ascending=False).reset_index()
# Out:
#        customer_city  order_id
# 0          sao paulo     14779
# 1     rio de janeiro      6468
# 2     belo horizonte      2640
# 3           brasilia      2036
# 4           curitiba      1468
# ...              ...       ...
# 4066        machados         1
# 4067      machadinho         1
# 4068        macaubal         1
# 4069       macambira         1
# 4070          zortea         1
#
# [4071 rows x 2 columns]

# %% [markdown]
# Total pendapatan

# %%
total_sales = round(data_ecommerce_df['price'].sum(), 2)  
mean_sales = round(data_ecommerce_df['price'].mean(), 2)
print('Total Sales:', total_sales)
print('Average Sales:', mean_sales)
# Out:
# Total Sales: 13005413.76
# Average Sales: 120.06

# %% [markdown]
# Total pendapatan berdasarkan produk

# %%
data_ecommerce_df.groupby(by='product_category_name').price.sum().sort_values(ascending=False).reset_index()
# Out:
#             product_category_name       price
# 0                    beleza_saude  1229587.49
# 1              relogios_presentes  1163187.91
# 2                 cama_mesa_banho  1022821.78
# 3                   esporte_lazer   952592.42
# 4          informatica_acessorios   887944.60
# ..                            ...         ...
# 68                         flores     1110.04
# 69                casa_conforto_2      760.27
# 70              cds_dvds_musicais      730.00
# 71  fashion_roupa_infanto_juvenil      519.95
# 72             seguros_e_servicos      283.29
#
# [73 rows x 2 columns]

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Bagaimana trend performa pemesanan dan pendapatan produk per bulan?

# %%
order_by_month = data_ecommerce_df.groupby('purchase_month_year').order_id.nunique().reset_index()
order_by_month = order_by_month.sort_values('purchase_month_year')
order_by_month
# Out:
#    purchase_month_year  order_id
# 0           2017-01-01       737
# 1           2017-02-01      1592
# 2           2017-03-01      2496
# 3           2017-04-01      2243
# 4           2017-05-01      3466
# 5           2017-06-01      3085
# 6           2017-07-01      3824
# 7           2017-08-01      4129
# 8           2017-09-01      4090
# 9           2017-10-01      4428
# 10          2017-11-01      7186
# 11          2017-12-01      5383
# 12          2018-01-01      6901
# 13          2018-02-01      6451
# 14          2018-03-01      6884
# 15          2018-04-01      6731
# 16          2018-05-01      6716
# 17          2018-06-01      6075
# 18          2018-07-01      6118
# 19          2018-08-01      6324

# %%
plt.figure(figsize=(12, 6))
plt.plot(order_by_month['purchase_month_year'], order_by_month['order_id'], marker='o')
plt.xlabel('Order Date')
plt.ylabel('Total Order')
plt.title('Total Order per Month (2017-2018)')
plt.xticks(rotation=45)
plt.show()

# %%
revenue_by_month = data_ecommerce_df.groupby('purchase_month_year').price.sum().reset_index()
revenue_by_month = revenue_by_month.sort_values('purchase_month_year')
revenue_by_month
# Out:
#    purchase_month_year      price
# 0           2017-01-01  108174.83
# 1           2017-02-01  224167.74
# 2           2017-03-01  352741.68
# 3           2017-04-01  332221.49
# 4           2017-05-01  478340.91
# 5           2017-06-01  417020.97
# 6           2017-07-01  478636.66
# 7           2017-08-01  549731.25
# 8           2017-09-01  601446.52
# 9           2017-10-01  631926.38
# 10          2017-11-01  973861.52
# 11          2017-12-01  710535.52
# 12          2018-01-01  903651.37
# 13          2018-02-01  813775.15
# 14          2018-03-01  936731.03
# 15          2018-04-01  965546.19
# 16          2018-05-01  974447.65
# 17          2018-06-01  853204.84
# 18          2018-07-01  862874.47
# 19          2018-08-01  836377.59

# %%
plt.figure(figsize=(12, 6))
plt.plot(revenue_by_month['purchase_month_year'], revenue_by_month['price'], marker='o')
plt.xlabel('Order Date')
plt.ylabel('Total Revenue')
plt.title('Total Revenue per Month (2017-2018)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Produk apa yang memiliki total pemesanan terbanyak dan terendah?

# %%
ecommerce_product = data_ecommerce_df.groupby(by='product_category_name').order_id.nunique().sort_values(ascending=False).reset_index().head(10)
ecommerce_product.head(20)
# Out:
#     product_category_name  order_id
# 0         cama_mesa_banho      9266
# 1            beleza_saude      8611
# 2           esporte_lazer      7510
# 3  informatica_acessorios      6517
# 4        moveis_decoracao      6254
# 5   utilidades_domesticas      5734
# 6      relogios_presentes      5489
# 7               telefonia      4085
# 8              automotivo      3801
# 9              brinquedos      3781

# %%
top_color = '#72BCD4'
default_color = '#D3D3D3'

plt.figure(figsize=(12, 6))
plt.barh(ecommerce_product['product_category_name'], ecommerce_product['order_id'], color=[top_color if city == ecommerce_product['product_category_name'].iloc[0] else default_color for city in ecommerce_product['product_category_name']])
plt.xlabel('Total Order')
plt.ylabel('Product Category')
plt.title('Products with The Most and The Lowest Orders')
plt.gca().invert_yaxis()

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))
colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="order_id", y="product_category_name", data=ecommerce_product.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Best Products", loc="center", fontsize=15)
ax[0].tick_params(axis ='y', labelsize=12)

sns.barplot(x="order_id", y="product_category_name", data=ecommerce_product.sort_values(by="order_id", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Worst Products", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)

plt.suptitle("Products with The Most and The Lowest Orders", fontsize=20)
plt.show()
# Out:
# C:\Users\arqam\AppData\Local\Temp\ipykernel_7812\1528947136.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="order_id", y="product_category_name", data=ecommerce_product.head(5), palette=colors, ax=ax[0])
# C:\Users\arqam\AppData\Local\Temp\ipykernel_7812\1528947136.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="order_id", y="product_category_name", data=ecommerce_product.sort_values(by="order_id", ascending=True).head(5), palette=colors, ax=ax[1])

# %% [markdown]
# ### Kota mana yang melakukan banyak pemesanan?

# %%
ecommerce_city = data_ecommerce_df.groupby(by='customer_city').order_id.nunique().sort_values(ascending=False).reset_index().head(10)
ecommerce_city
# Out:
#            customer_city  order_id
# 0              sao paulo     14779
# 1         rio de janeiro      6468
# 2         belo horizonte      2640
# 3               brasilia      2036
# 4               curitiba      1468
# 5               campinas      1385
# 6           porto alegre      1321
# 7               salvador      1170
# 8              guarulhos      1127
# 9  sao bernardo do campo       891

# %%
top_color = '#72BCD4'
default_color = '#D3D3D3'

plt.figure(figsize=(12, 6))
plt.barh(ecommerce_city['customer_city'], ecommerce_city['order_id'], color=[top_color if city == ecommerce_city['customer_city'].iloc[0] else default_color for city in ecommerce_city['customer_city']])
plt.xlabel('Total Order')
plt.ylabel('City Name')
plt.title('Cities with The Most Orders', loc="center", fontsize=15)
plt.gca().invert_yaxis()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Berdasarkan analisis, bulan Januari 2017 menunjukkan angka pemesanan dan pendapatan terendah, dengan total pesanan sebanyak 737 dan pendapatan paling minim. Sebaliknya, bulan November 2017 mencatat puncak pemesanan dengan 7186 pesanan, diduga dipengaruhi oleh suatu event tertentu. Meskipun pada tahun 2018 terjadi sedikit penurunan pesanan menjadi sekitar enam ribu, perusahaan perlu mengembangkan strategi pemasaran untuk mencegah penurunan tersebut. Demikian juga, total pendapatan tertinggi juga tercatat pada bulan November 2017, sementara tiga bulan terakhir tahun 2018 mengalami penurunan pendapatan. Meskipun data 2018 tidak mencakup pendapatan hingga akhir tahun, perusahaan juga perlu merancang strategi pemasaran guna menghindari risiko penurunan pendapatan yang potensial.
#
# - Dari seluruh 73 produk yang dijual melalui platform E-commerce, produk "cama_mesa_banho" mencatat jumlah pesanan tertinggi, mencapai 9266 pesanan. Di sisi lain, produk "brinquedos" memiliki pesanan terendah dengan total 3781 pesanan. Ini menunjukkan bahwa "cama_mesa_banho" adalah produk paling diminati oleh pelanggan. Oleh karena itu, perusahaan disarankan untuk mengembangkan strategi pemasaran khusus bagi produk yang memiliki jumlah pesanan lebih rendah.
#
# - Dari jumlah total 4071 kota, "sao paulo" menonjol sebagai kota dengan jumlah pesanan tertinggi melalui platform E-commerce, mencapai 14779 pesanan. Sementara itu, "sao bernardo do campo" merupakan kota dengan pesanan terendah, hanya mencapai 891 pesanan. Perbedaan yang signifikan dalam jumlah pesanan antar kota menunjukkan bahwa "sao paulo" memiliki tingkat aktivitas belanja online yang tinggi, menarik banyak pelanggan. Oleh karena itu, perusahaan dapat mengarahkan strategi bisnis dan pemasaran khusus untuk memaksimalkan potensi pendapatan dari kota dengan pesanan terbanyak ini.
